# %%
import pandas as pd
import matplotlib.pyplot as plt
from tabulate import tabulate

# %%
df=pd.read_csv('Hospital.csv')

# %%
df.head()
# Out:
#                               Hospital          Store  Year  Month  \
# 0  Saad Hospital & Cardiac Care Center  Main Pharmacy  2021      5
# 1  Saad Hospital & Cardiac Care Center  Main Pharmacy  2021      5
# 2  Saad Hospital & Cardiac Care Center  Main Pharmacy  2021      5
# 3  Saad Hospital & Cardiac Care Center  Main Pharmacy  2021      5
# 4  Saad Hospital & Cardiac Care Center  Main Pharmacy  2021      5
#
#                                                 Item Transaction     Y  \
# 0                      Cap Aksoxime (Cefixime) 400mg  Adjustment  10.0
# 1                      Cap Aksoxime (Cefixime) 400mg   Inventory   0.0
# 2  Cap Amoxil (Amoxicillin + Amoxicillin) 500mg/5...   Inventory   0.0
# 3  Cap Amoxil (Amoxicillin + Amoxicillin) 500mg/5...         POS  10.0
# 4                       Cap Capzol (Omeprazole) 20mg   Inventory   0.0
#
#    Received
# 0         0
# 1        10
# 2        10
# 3         0
# 4         5

# %%
df.shape
# Out:
# (86821, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86821 entries, 0 to 86820
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Hospital     86821 non-null  object
#  1   Store        86821 non-null  object
#  2   Year         86821 non-null  int64
#  3   Month        86821 non-null  int64
#  4   Item         86821 non-null  object
#  5   Transaction  86821 non-null  object
#  6   Y            86821 non-null  float64
#  7   Received     86821 non-null  int64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 5.3+ MB

# %%
df.describe()
# Out:
#                Year         Month             Y      Received
# count  86821.000000  86821.000000  86821.000000  86821.000000
# mean    2022.497023      6.418113     57.693001     58.965331
# std        0.977084      3.413358    222.324211    236.076773
# min     2021.000000      1.000000      0.000000      0.000000
# 25%     2022.000000      3.000000      0.000000      0.000000
# 50%     2023.000000      6.000000      3.000000      2.000000
# 75%     2023.000000      9.000000     28.000000     26.000000
# max     2024.000000     12.000000  11000.000000  14200.000000

# %%
df.dropna()
# Out:
#                                   Hospital          Store  Year  Month  \
# 0      Saad Hospital & Cardiac Care Center  Main Pharmacy  2021      5
# 1      Saad Hospital & Cardiac Care Center  Main Pharmacy  2021      5
# 2      Saad Hospital & Cardiac Care Center  Main Pharmacy  2021      5
# 3      Saad Hospital & Cardiac Care Center  Main Pharmacy  2021      5
# 4      Saad Hospital & Cardiac Care Center  Main Pharmacy  2021      5
# ...                                    ...            ...   ...    ...
# 86816  Saad Hospital & Cardiac Care Center  Main Pharmacy  2024      6
# 86817  Saad Hospital & Cardiac Care Center  Main Pharmacy  2024      6
# 86818  Saad Hospital & Cardiac Care Center  Main Pharmacy  2024      6
# 86819  Saad Hospital & Cardiac Care Center  Main Pharmacy  2024      6
# 86820  Saad Hospital & Cardiac Care Center  Main Pharmacy  2024      6
#
#                                                     Item Transaction     Y  \
# ...

# %%
unique_df = df.drop_duplicates()

# %%
unique_df
# Out:
#                                   Hospital          Store  Year  Month  \
# 0      Saad Hospital & Cardiac Care Center  Main Pharmacy  2021      5
# 1      Saad Hospital & Cardiac Care Center  Main Pharmacy  2021      5
# 2      Saad Hospital & Cardiac Care Center  Main Pharmacy  2021      5
# 3      Saad Hospital & Cardiac Care Center  Main Pharmacy  2021      5
# 4      Saad Hospital & Cardiac Care Center  Main Pharmacy  2021      5
# ...                                    ...            ...   ...    ...
# 86816  Saad Hospital & Cardiac Care Center  Main Pharmacy  2024      6
# 86817  Saad Hospital & Cardiac Care Center  Main Pharmacy  2024      6
# 86818  Saad Hospital & Cardiac Care Center  Main Pharmacy  2024      6
# 86819  Saad Hospital & Cardiac Care Center  Main Pharmacy  2024      6
# 86820  Saad Hospital & Cardiac Care Center  Main Pharmacy  2024      6
#
#                                                     Item Transaction     Y  \
# ...

# %% [markdown]
# # Taking POS for analysis

# %%
filtered_df = df[df['Transaction'] == 'POS']

# %%
filtered_df
# Out:
#                                   Hospital          Store  Year  Month  \
# 3      Saad Hospital & Cardiac Care Center  Main Pharmacy  2021      5
# 7      Saad Hospital & Cardiac Care Center  Main Pharmacy  2021      5
# 11     Saad Hospital & Cardiac Care Center  Main Pharmacy  2021      5
# 13     Saad Hospital & Cardiac Care Center  Main Pharmacy  2021      5
# 15     Saad Hospital & Cardiac Care Center  Main Pharmacy  2021      5
# ...                                    ...            ...   ...    ...
# 86808  Saad Hospital & Cardiac Care Center  Main Pharmacy  2024      6
# 86811  Saad Hospital & Cardiac Care Center  Main Pharmacy  2024      6
# 86813  Saad Hospital & Cardiac Care Center  Main Pharmacy  2024      6
# 86817  Saad Hospital & Cardiac Care Center  Main Pharmacy  2024      6
# 86820  Saad Hospital & Cardiac Care Center  Main Pharmacy  2024      6
#
#                                                     Item Transaction      Y  \
# ...

# %% [markdown]
# # Taking first five most selling medicines for analysis

# %%
panadol=df[df.Item=='Tab Panadol  (Paracetamol) 500mg']
panadol_sum = panadol.groupby(['Year','Month'])['Y'].sum()
panadol_sum.head()
# Out:
# Year  Month
# 2021  6          94.0
#       7        2715.0
#       8        4835.0
#       9        2227.0
#       10       3244.0
# Name: Y, dtype: float64

# %%
Flagyl=df[df.Item=='Tab Flagyl (Metronidazole ) 400mg']
Flagyl_sum = Flagyl.groupby(['Year','Month'])['Y'].sum()
Flagyl_sum.head()
# Out:
# Year  Month
# 2021  6          39.0
#       7        6579.0
#       8        2659.0
#       9        2336.0
#       10       2687.0
# Name: Y, dtype: float64

# %%
Flagyl=df[df.Item=='Tab Flagyl (Metronidazole ) 400mg']
Flagyl_sum = Flagyl.groupby(['Year','Month'])['Y'].sum()
Flagyl_sum.head()
# Out:
# Year  Month
# 2021  6          39.0
#       7        6579.0
#       8        2659.0
#       9        2336.0
#       10       2687.0
# Name: Y, dtype: float64

# %% [markdown]
# # Received item over different time

# %%
received=filtered_df[['Item','Y']]

# %%
received
# Out:
#                                                     Item      Y
# 3      Cap Amoxil (Amoxicillin + Amoxicillin) 500mg/5...   10.0
# 7      Cap Combivair (Budesonide+Formoterol Fumarate)...   25.0
# 11                 Cap Doxium (calcium dobesilate) 500mg   50.0
# 13                                            Cap espole   12.0
# 15                                      IV infusion sets  100.0
# ...                                                  ...    ...
# 86808                                          Urine pot    3.0
# 86811                                     Vicryl 1 bajwa   39.0
# 86813                                         Vicryl 2/0    6.0
# 86817                                              wipes   20.0
# 86820                                         Yanker set    7.0
#
# [45504 rows x 2 columns]

# %%
medicine_sums = filtered_df.groupby('Item')['Y'].sum()
medicine_sums
# Out:
# Item
#  Dynamic Drain 18 no         5.0
#  dynamic Drain 16 no         1.0
# 0.5cc syrinje               60.0
# 10CC SYRINJE             87427.0
# 18#vasofix                  59.0
#                           ...
# vicks balm                 142.0
# vicryl 1 ethicon             4.0
# wipes                     2614.0
# wrist support comfort        1.0
# zeesole ns 100ml          2443.0
# Name: Y, Length: 3115, dtype: float64

# %%
top_200_medicines = medicine_sums.nlargest(200)
table_data = pd.DataFrame(top_200_medicines).reset_index()

print(tabulate(table_data, headers=['Item', 'Y'], tablefmt='grid'))
# Out:
# +-----+---------------------------------------------------------------------------------+--------+
# |     | Item                                                                            |      Y |
# +=====+=================================================================================+========+
# |   0 | Tab Panadol  (Paracetamol) 500mg                                                | 106649 |
# +-----+---------------------------------------------------------------------------------+--------+
# |   1 | Tab Flagyl (Metronidazole ) 400mg                                               |  93281 |
# +-----+---------------------------------------------------------------------------------+--------+
# |   2 | 10CC SYRINJE                                                                    |  87427 |
# +-----+---------------------------------------------------------------------------------+--------+
# ...

# %%
# Sample data (replace this with your actual data)
items = ["Tab Panadol","Tab Flagyl","10CC SYRINJE"," Cap Elezo (Iron) 150mg  ",
         " Tab Intig-D (Ossein Mineral Complex + Vitamin D) 830mg/400I-U ",'Tab Neoprad (levosulpride) 25mg',
         "Tab deltacortril-ec (Prednisolone) 5mg  ","Tab Spasfone (Phloroglucinol hydrate + trimethylphloroglucinol) ",
         "Tab ITP (Itopride Hcl) 50mg ",'Tab gencox (Etoricoxib) 60mg'," IV set "]

sales = [106649,93281,87427,87117,74672,72901,62700,61935,58955,57964,53114]

# Create a basic line chart
plt.plot(items, sales, marker='o', linestyle='--', color='g')
#plt.plot(items,sales1,color='b')
plt.title('Total Sales for Different Items')
plt.xlabel('Items')
plt.ylabel('Sales')
plt.grid(True)
plt.xticks(rotation=90)  # Rotate x-axis labels for readability
#plt.tight_layout()  # Adjust layout
plt.show()

# %%
table_data.head()
# Out:
#                                                 Item         Y
# 0                   Tab Panadol  (Paracetamol) 500mg  106649.0
# 1                  Tab Flagyl (Metronidazole ) 400mg   93281.0
# 2                                       10CC SYRINJE   87427.0
# 3                             Cap Elezo (Iron) 150mg   87117.0
# 4  Tab Intig-D (Ossein Mineral Complex + Vitamin ...   74672.0

# %% [markdown]
# # Transaction caried out most

# %% [markdown]
# # Yearly Sales

# %%
Yearly_sales=filtered_df[['Year','Item','Y']]
Yearly_sales
# Out:
#        Year                                               Item      Y
# 3      2021  Cap Amoxil (Amoxicillin + Amoxicillin) 500mg/5...   10.0
# 7      2021  Cap Combivair (Budesonide+Formoterol Fumarate)...   25.0
# 11     2021              Cap Doxium (calcium dobesilate) 500mg   50.0
# 13     2021                                         Cap espole   12.0
# 15     2021                                   IV infusion sets  100.0
# ...     ...                                                ...    ...
# 86808  2024                                          Urine pot    3.0
# 86811  2024                                     Vicryl 1 bajwa   39.0
# 86813  2024                                         Vicryl 2/0    6.0
# 86817  2024                                              wipes   20.0
# 86820  2024                                         Yanker set    7.0
#
# [45504 rows x 3 columns]

# %%
#Yearly Sales
Sales_over_year = filtered_df.groupby(['Year','Item'])['Y'].sum()
Sales_over_year
# Out:
# Year  Item
# 2021  0.5cc syrinje                  1.0
#       10CC SYRINJE               17089.0
#       18#vasofix                    25.0
#       1CC BD INSULINE SYRINJE      632.0
#       1CC SYRINJE                 1068.0
#                                   ...
# 2024  silk 2                         2.0
#       spirit 120ml                  40.0
#       spirit 50ml                   12.0
#       wipes                        280.0
#       zeesole ns 100ml             168.0
# Name: Y, Length: 8006, dtype: float64

# %%
#Monthly Sales
Monthly_sales=filtered_df[['Month','Item','Y']]
Monthly_sales
# Out:
#        Month                                               Item      Y
# 3          5  Cap Amoxil (Amoxicillin + Amoxicillin) 500mg/5...   10.0
# 7          5  Cap Combivair (Budesonide+Formoterol Fumarate)...   25.0
# 11         5              Cap Doxium (calcium dobesilate) 500mg   50.0
# 13         5                                         Cap espole   12.0
# 15         5                                   IV infusion sets  100.0
# ...      ...                                                ...    ...
# 86808      6                                          Urine pot    3.0
# 86811      6                                     Vicryl 1 bajwa   39.0
# 86813      6                                         Vicryl 2/0    6.0
# 86817      6                                              wipes   20.0
# 86820      6                                         Yanker set    7.0
#
# [45504 rows x 3 columns]

# %%
Sales_over_month = filtered_df.groupby(['Month','Item'])['Y'].sum()
Sales_over_month
# Out:
# Month  Item
# 1       Dynamic Drain 18 no          1.0
#        0.5cc syrinje                 3.0
#        10CC SYRINJE               7092.0
#        18#vasofix                    2.0
#        1CC BD INSULINE SYRINJE     216.0
#                                    ...
# 12     surgee Tulle                 11.0
#        vicks balm                   18.0
#        vicryl 1 ethicon              1.0
#        wipes                       283.0
#        zeesole ns 100ml             58.0
# Name: Y, Length: 24194, dtype: float64

# %%
#Total Sales
Total_sales=filtered_df[['Year','Month','Item','Y']]
Total_sales
# Out:
#        Year  Month                                               Item      Y
# 3      2021      5  Cap Amoxil (Amoxicillin + Amoxicillin) 500mg/5...   10.0
# 7      2021      5  Cap Combivair (Budesonide+Formoterol Fumarate)...   25.0
# 11     2021      5              Cap Doxium (calcium dobesilate) 500mg   50.0
# 13     2021      5                                         Cap espole   12.0
# 15     2021      5                                   IV infusion sets  100.0
# ...     ...    ...                                                ...    ...
# 86808  2024      6                                          Urine pot    3.0
# 86811  2024      6                                     Vicryl 1 bajwa   39.0
# 86813  2024      6                                         Vicryl 2/0    6.0
# 86817  2024      6                                              wipes   20.0
# 86820  2024      6                                         Yanker set    7.0
#
# [45504 rows x 4 columns]

# %%
Total_sales = filtered_df.groupby(['Year','Month','Item'])['Y'].sum()
Total_sales
# Out:
# Year  Month  Item
# 2021  5      Cap Amoxil (Amoxicillin + Amoxicillin) 500mg/500mg       10.0
#              Cap Combivair (Budesonide+Formoterol Fumarate) 200mg     25.0
#              Cap Doxium (calcium dobesilate) 500mg                    50.0
#              Cap espole                                               12.0
#              IV infusion sets                                        100.0
#                                                                      ...
# 2024  6      m/w enziclor mouth wash 240ml                             5.0
#              opsite(10*14)                                            10.0
#              polysling[adult]                                          1.0
#              spirit 120ml                                             10.0
#              wipes                                                    20.0
# Name: Y, Length: 45504, dtype: float64

# %% [markdown]
# # Transactions over time

# %%
Total_Transaction=filtered_df[['Year','Month','Transaction','Y']]
Total_Transaction
# Out:
#        Year  Month Transaction      Y
# 3      2021      5         POS   10.0
# 7      2021      5         POS   25.0
# 11     2021      5         POS   50.0
# 13     2021      5         POS   12.0
# 15     2021      5         POS  100.0
# ...     ...    ...         ...    ...
# 86808  2024      6         POS    3.0
# 86811  2024      6         POS   39.0
# 86813  2024      6         POS    6.0
# 86817  2024      6         POS   20.0
# 86820  2024      6         POS    7.0
#
# [45504 rows x 4 columns]

# %%
Total_sales = filtered_df.groupby(['Year','Month','Item'])['Y'].sum()
Total_sales
# Out:
# Year  Month  Item
# 2021  5      Cap Amoxil (Amoxicillin + Amoxicillin) 500mg/500mg       10.0
#              Cap Combivair (Budesonide+Formoterol Fumarate) 200mg     25.0
#              Cap Doxium (calcium dobesilate) 500mg                    50.0
#              Cap espole                                               12.0
#              IV infusion sets                                        100.0
#                                                                      ...
# 2024  6      m/w enziclor mouth wash 240ml                             5.0
#              opsite(10*14)                                            10.0
#              polysling[adult]                                          1.0
#              spirit 120ml                                             10.0
#              wipes                                                    20.0
# Name: Y, Length: 45504, dtype: float64

# %%
#sorted items in descending order
sorted_sales = Total_sales.nlargest(3300).sort_values(ascending=[False])
table_data = pd.DataFrame(sorted_sales).reset_index()

print(tabulate(table_data, headers=['Year', 'Month', 'Item','Y'], tablefmt='grid'))
# Out:
# +------+--------+---------+---------------------------------------------------------------------------+------+
# |      |   Year |   Month | Item                                                                      |    Y |
# +======+========+=========+===========================================================================+======+
# |    0 |   2021 |       7 | Tab Flagyl (Metronidazole ) 400mg                                         | 6579 |
# +------+--------+---------+---------------------------------------------------------------------------+------+
# |    1 |   2022 |       1 | Tab Panadol  (Paracetamol) 500mg                                          | 5502 |
# +------+--------+---------+---------------------------------------------------------------------------+------+
# |    2 |   2022 |       3 | Tab Neoprad (levosulpride) 25mg                                           | 5321 |
# ...

# %%
# Assuming 'Total_sales' is your Pandas Series
sorted_sales = Total_sales.nlargest(3300).sort_values(ascending=False)
table_data = pd.DataFrame(sorted_sales).reset_index()

# Sort by 'Year' and 'Month' in ascending order
table_data.sort_values(by=['Year', 'Month'], ascending=[True, True], inplace=True)

print(tabulate(table_data, headers=['Year', 'Month', 'Item', 'Y'], tablefmt='grid'))
# Out:
# +------+--------+---------+---------------------------------------------------------------------------+------+
# |      |   Year |   Month | Item                                                                      |    Y |
# +======+========+=========+===========================================================================+======+
# |    0 |   2021 |       7 | Tab Flagyl (Metronidazole ) 400mg                                         | 6579 |
# +------+--------+---------+---------------------------------------------------------------------------+------+
# |  106 |   2021 |       7 | Tab Roxvita (Multivitamin)                                                | 2839 |
# +------+--------+---------+---------------------------------------------------------------------------+------+
# |  112 |   2021 |       7 | 10CC SYRINJE                                                              | 2797 |
# ...

# %%
table_data
# Out:
#       Year  Month                                               Item       Y
# 0     2021      7                  Tab Flagyl (Metronidazole ) 400mg  6579.0
# 106   2021      7                         Tab Roxvita (Multivitamin)  2839.0
# 112   2021      7                                       10CC SYRINJE  2797.0
# 122   2021      7                   Tab Panadol  (Paracetamol) 500mg  2715.0
# 150   2021      7                             Cap Elezo (Iron) 150mg  2555.0
# ...    ...    ...                                                ...     ...
# 3104  2024      6            Tab ponstan fort (mefenamic acid) 500mg   357.0
# 3137  2024      6                 Cap Thewril (Thiocolchicoside) 4mg   353.0
# 3160  2024      6  Cap Combivair (Budesonide+Formoterol Fumarate)...   350.0
# 3188  2024      6                                        22 #vasofix   347.0
# 3236  2024      6             Sach Freehale (Montelukast Sodium) 4mg   342.0
#
# [3300 rows x 4 columns]
